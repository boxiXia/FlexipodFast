# %%
import os
# https://discuss.pytorch.org/t/how-to-change-the-default-device-of-gpu-device-ids-0/1041/24
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]=f"{1}"

import torch
print(f"current_device:{torch.cuda.current_device()}")
print(f"device_count:{torch.cuda.device_count()}")
device = torch.device("cuda")
# Out:
# current_device:0
# device_count:1

# %%
import gym
env = gym.make('CartPole-v1')
for i_episode in range(20):
    observation = env.reset()
    for t in range(100):
        env.render()
        print(observation)
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
env.close()
# Out:
# [ 0.02573004 -0.01465614  0.03378908  0.01222349]
# [ 0.02543692  0.17996535  0.03403355 -0.26961   ]
# [ 0.02903623  0.37458551  0.02864135 -0.55136726]
# [ 0.03652794  0.56929374  0.017614   -0.83489041]
# [ 0.04791381  0.37393564  0.0009162  -0.53672047]
# [ 0.05539253  0.17880082 -0.00981821 -0.243749  ]
# [ 0.05896854 -0.01617953 -0.01469319  0.04582091]
# [ 0.05864495  0.17915    -0.01377678 -0.2514614 ]
# [ 0.06222795  0.37446594 -0.018806   -0.54845775]
# [ 0.06971727  0.17961315 -0.02977516 -0.2617589 ]
# [ 0.07330953 -0.01507139 -0.03501034  0.02138588]
# [ 0.07300811 -0.20967423 -0.03458262  0.30282032]
# [ 0.06881462 -0.40428668 -0.02852621  0.58439919]
# [ 0.06072889 -0.59899766 -0.01683823  0.86796126]
# [ 4.87489349e-02 -7.93886500e-01  5.20996220e-04  1.15530288e+00]
# [ 0.0328712  -0.59877135  0.02362705  0.86278336]
# [ 0.02089578 -0.79420688  0.04088272  1.16280055]
# [ 0.00501164 -0.98983667  0.06413873  1.46801621]
# ...

# %% [markdown]
# # ddpg

# %%
from ddpg import DDPGagent
from ddpg.utils import OUNoise, NormalizedEnv

# %%
# env = gym.make("Pendulum-v0")
# env.reset()
# env.step([0.1])

# %%
import sys
import gym
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# from DDPG import DDPGagent
# from utils import *

env = NormalizedEnv(gym.make("Pendulum-v0"))

# env = gym.make('BipedalWalker-v3')

agent = DDPGagent(env)
noise = OUNoise(env.action_space)
batch_size = 256
rewards = []
avg_rewards = []
# Out:
# 1

# %%
for episode in range(100):
    state = env.reset()
    noise.reset()
    episode_reward = 0
    
    for step in range(1000):
        action = agent.get_action(state)
        action = noise.get_action(action, step)
        new_state, reward, done, _ = env.step(action) 
        agent.memory.push(state, action, reward, new_state, done)
        
        if len(agent.memory) > batch_size:
            agent.update(batch_size)        
        
        state = new_state
        episode_reward += reward
        if done:
            break

    rewards.append(episode_reward)
    avg_rewards.append(np.mean(rewards[-10:]))
    sys.stdout.write("episode: {}, reward: {}, average _reward: {} \n".format(episode, np.round(episode_reward, decimals=2), np.mean(rewards[-10:])))


plt.plot(rewards)
plt.plot(avg_rewards)
plt.plot()
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.show()
# Out:
# episode: 0, reward: -1236.14, average _reward: -1236.1381648300444
# episode: 1, reward: -1384.43, average _reward: -1310.2816563811361
# episode: 2, reward: -1675.19, average _reward: -1431.91864354692
# episode: 3, reward: -1373.1, average _reward: -1417.2141295885922
# episode: 4, reward: -1200.54, average _reward: -1373.8798254265366
# episode: 5, reward: -1029.69, average _reward: -1316.5141433442716
# episode: 6, reward: -949.64, average _reward: -1264.1037756842888
# episode: 7, reward: -764.24, average _reward: -1201.6211158784427
# episode: 8, reward: -517.06, average _reward: -1125.5582369212575
# episode: 9, reward: -252.53, average _reward: -1038.2553364027376
# episode: 10, reward: -643.16, average _reward: -978.9578877025957
# episode: 11, reward: -633.3, average _reward: -903.8452573681282
# episode: 12, reward: -484.58, average _reward: -784.7838936248056
# episode: 13, reward: -620.84, average _reward: -709.5580468474396
# ...

# %%
state = env.reset()
noise.reset()
episode_reward = 0

for step in range(500):
    env.render()
    action = agent.get_action(state)
    action = noise.get_action(action, step)
    new_state, reward, done, _ = env.step(action) 
    agent.memory.push(state, action, reward, new_state, done)

    if len(agent.memory) > batch_size:
        agent.update(batch_size)        

    state = new_state
    episode_reward += reward
    if done:
        break
env.close()

# %%
from flexipod_env import FlexipodEnv
import gym
import time
import numpy as np
import msgpack
import socket
import warnings

# %%
env = FlexipodEnv(dof = 12)
# env.sock.sendto(env.resume_cmd_b,env.remote_address)
# env.sock.sendto(env.pause_cmd_b,env.remote_address)
# env.step((np.random.random(12)*1).tolist())
# for k in range(100):
#     env.reset()

# %%
# %timeit _=env.receive()
# Out:
# 2.04 ms ± 70.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
env.startSimulation()
# env.endSimulation()

# %%
for k in range(5):
    env.reset()
    env.send_sock.sendto(env.resume_cmd_b,env.remote_address)
    for t in range(1000):
        observation,reward,done,_=env.step(((-0.5+np.random.random(12))*5).tolist())
        if done:
            break
#     env.sock.sendto(env.pause_cmd_b,env.remote_address)
env.send_sock.sendto(env.pause_cmd_b,env.remote_address)
# Out:
# 8

# %%
env.action_space
# Out:
# Box(-1.0, 1.0, (12,), float32)

# %%
env.observation_space
# Out:
# Box(-30.0, 30.0, (52,), float32)

# %%
import os
# https://discuss.pytorch.org/t/how-to-change-the-default-device-of-gpu-device-ids-0/1041/24
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]=f"{1}"

import torch
print(f"current_device:{torch.cuda.current_device()}")
print(f"device_count:{torch.cuda.device_count()}")
device = torch.device("cuda")


import sys
import gym
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ddpg import DDPGagent
from ddpg.utils import OUNoise, NormalizedEnv
from flexipod_env import FlexipodEnv

env = FlexipodEnv(dof = 12)
env = NormalizedEnv(env)

agent = DDPGagent(env)
noise = OUNoise(env.action_space)
batch_size = 256
rewards = []
avg_rewards = []
episode_lens = []
# Out:
# current_device:0
# device_count:2
# Destructor called, FlexipodEnv deleted.
# 12

# %%
for episode in range(20000):
    state = env.reset()
    noise.reset()
    episode_reward = 0
#     env.sock.sendto(env.resume_cmd_b,env.remote_address)
    for step in range(2000):
        action = agent.get_action(state)
        action = noise.get_action(action, step)
        new_state, reward, done, _ = env.step(action) 
        agent.memory.push(state, action, reward, new_state, done)
        
        if len(agent.memory) > batch_size:
            agent.update(batch_size)        
        
        state = new_state
        episode_reward += reward
        if done:
            break
    episode_lens.append(step+1)
    rewards.append(episode_reward)
    avg_rewards.append(np.mean(rewards[-10:]))
    sys.stdout.write(f"episode: {episode}, steps:{step}, reward: {np.round(episode_reward, decimals=2)}, average _reward: {np.mean(rewards[-10:])} \n")

env.send_sock.sendto(env.pause_cmd_b,env.remote_address)

plt.plot(rewards)
plt.plot(avg_rewards)
plt.plot()
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.show()
# Out:
# episode: 0, steps:228, reward: 275.28, average _reward: 275.27648676620663
# episode: 1, steps:62, reward: 71.3, average _reward: 173.28870142220381
# episode: 2, steps:37, reward: 44.48, average _reward: 130.35285403629481
# episode: 3, steps:36, reward: 43.86, average _reward: 108.7291347285981
# episode: 4, steps:34, reward: 42.15, average _reward: 95.41270614251856
# episode: 5, steps:27, reward: 30.86, average _reward: 84.6546177660772
# episode: 6, steps:16, reward: 19.84, average _reward: 75.39531795478558
# episode: 7, steps:20, reward: 24.3, average _reward: 69.00814078038623
# episode: 8, steps:32, reward: 38.24, average _reward: 65.58942754808685
# episode: 9, steps:34, reward: 38.73, average _reward: 62.90354287340027
# episode: 10, steps:30, reward: 34.65, average _reward: 38.84112011889279
# episode: 11, steps:21, reward: 25.87, average _reward: 34.29809114746573
# episode: 12, steps:36, reward: 40.01, average _reward: 33.85137257719261
# ...

# %%
avg_episode_lens = np.array([np.mean(episode_lens[:t][-100:-10]) for t in range(1,len(episode_lens)+1)])
# Out:
# C:\Users\boxi\miniconda3\envs\flexipod\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\boxi\miniconda3\envs\flexipod\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plt.style.use('seaborn-whitegrid')
# %config InlineBackend.figure_format = 'retina'
plt.figure(dpi=300,figsize=(4,4))
plt.plot(episode_lens,label="reward")
# plt.plot(avg_rewards)
plt.plot(avg_episode_lens,label ="avg reward")
plt.plot()
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.plot([105]*len(episode_lens),label = "zero control")
plt.legend()
plt.show()

# %%
for episode in range(20):
    state = env.reset()
    noise.reset()
    episode_reward = 0
    env.send_sock.sendto(env.resume_cmd_b,env.remote_address)
    for step in range(2000):
        action = agent.get_action(state)
#         action = action.tolist()
#         action = [0.]*6
        new_state, reward, done, _ = env.step(action) 
#         new_state, reward, done, _ = env.step()   

        state = new_state
        episode_reward += reward
        if done:
            break
    print(step)
# Out:
# 155
# 178
# 147
# 153
# 136
# 99
# 103
# 149
# 99
# 96
# 114
# 120
# 95
# 97
# 155
# 142
# 108
# 99
# 130
# 104

# %%
for a in cmd_action:
    print(type(a))
# Out:
# <class 'numpy.float32'>
# <class 'numpy.float32'>
# <class 'int'>
# <class 'int'>
# <class 'numpy.float32'>
# <class 'numpy.float32'>
# <class 'numpy.float32'>
# <class 'numpy.float32'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
agent.get_action(state)
# Out:
# array([-0.99309856, -0.99930644, -0.9981547 ,  1.        , -0.9594941 ,
#         0.97929066], dtype=float32)

# %%
env.step(action)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-815425c95cb8> in <module>
# ----> 1 env.step(action)
#
# d:\repo\gym\gym\core.py in step(self, action)
#     290
#     291     def step(self, action):
# --> 292         return self.env.step(self.action(action))
#     293
#     294     def action(self, action):
#
# <ipython-input-13-c1c5434cca82> in step(self, action)
#     122 #             cmd_action = action if type(action) is list else action.tolist()
#     123
# --> 124             step_cmd_b = self.packer.pack([self.UDP_MOTOR_VEL_COMMEND,time.time(),cmd_action])
#     125             num_bytes_send = self.sock.sendto(step_cmd_b,self.remote_address)
#     126         self._closeSocket()
#
# msgpack/_packer.pyx in msgpack._cmsgpack.Packer.pack()
#
# msgpack/_packer.pyx in msgpack._cmsgpack.Packer.pack()
#
# ...

# %%
cmd_action = [
    action[0],  # 0
    action[1],  # 1
    0,          # 2 
    0,          # 3
    action[2],  # 4  
    action[3],  # 5 
    action[4],  # 6 
    action[5],  # 7 
    0,          # 8 
    0,          # 9 
    0,          # 10
    0           # 11
]

# %%
type(action[0])
# Out:
# numpy.float32
